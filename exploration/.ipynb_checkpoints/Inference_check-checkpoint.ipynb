# %% [markdown]
# ## 0. Libarary 불러오기 및 경로설정

# %%
import os
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
import numpy as np

import torchvision
from torchvision import transforms, models
from torchvision.transforms import Resize, ToTensor, Normalize

import pprint

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# 테스트 데이터셋 폴더 경로를 지정해주세요.
test_dir = '/opt/ml/input/data/eval'

# %%
# !pip install torchvision==0.11.3

# %%
# !gpustat -i
# Out:
# 7789069e1d74b5             Wed Mar  2 06:57:01 2022  450.80.02
# [0] Tesla V100-PCIE-32GB | 34'C,   0 % |     4 / 32510 MB |
# 8789069e1d74b5             Wed Mar  2 06:57:02 2022  450.80.02
# [0] Tesla V100-PCIE-32GB | 34'C,   0 % |     4 / 32510 MB |
# ^C
# 88

# %%
model = torch.load("/opt/ml/code/model_727.pt")
model.eval()

# %%
trans = transforms.Compose([
    Resize((224, 224), Image.BILINEAR),
    ToTensor(),
    Normalize(mean=(0.5, 0.5, 0.5), std=(0.2, 0.2, 0.2)),
])
BATCH_SIZE = 128
test_dataset = CustomDataset(test_df, trans)
test_iter = torch.utils.data.DataLoader(test_dataset,batch_size=BATCH_SIZE,shuffle=True,num_workers=1)

# %%
#train_accr = func_eval(model,train_iter,device)
test_accr = func_eval(model,test_iter,device)
print ("test_accr:[%.3f]."%(test_accr))
# Out:
# test_accr:[0.727].

# %% [markdown]
# # Inference

# %%
s2 = pd.read_csv('/opt/ml/output/output_aug_true.csv').set_index('ImageID')
s3 = pd.read_csv('/opt/ml/output/output_aug_true2.csv').set_index('ImageID')
s4 = pd.read_csv('/opt/ml/output/output_aug_false.csv').set_index('ImageID')
s5 = pd.read_csv('/opt/ml/output/output_aug_false2.csv').set_index('ImageID')

# %%
#pd.concat([df_1, df_3], axis=1)
#df = submission['ans']
s1 = submission.set_index('ImageID')
#df.apply(lambda x: x.value_counts(), axis=1).fillna(0).astype(int)
# 출처: https://rfriend.tistory.com/256 [R, Python 분석과 프로그래밍의 친구 (by R Friend)]

# %%
df = pd.concat([s1,s2,s3,s4,s5], axis=1)
df
# Out:
#                                               ans  ans  ans  ans  ans
# ImageID
# cbc5c6e168e63498590db46022617123f1fe1268.jpg   13   13   13   13   13
# 0e72482bf56b3581c081f7da2a6180b8792c7089.jpg    1    1    1    1    1
# b549040c49190cedc41327748aeb197c1670f14d.jpg   13   13   13   13   13
# 4f9cb2a045c6d5b9e50ad3459ea7b791eb6e18bc.jpg   13   13   14   13   14
# 248428d9a4a5b6229a7081c32851b90cb8d38d0c.jpg   12   12   12   12   12
# ...                                           ...  ...  ...  ...  ...
# d71d4570505d6af8f777690e63edfa8d85ea4476.jpg    1    1    1    1    1
# 6cf1300e8e218716728d5820c0bab553306c2cfd.jpg    4    4    4    4    4
# 8140edbba31c3a824e817e6d5fb95343199e2387.jpg    9    9    9    9    9
# 030d439efe6fb5a7bafda45a393fc19f2bf57f54.jpg    1    1    1    1    1
# f1e0b9594ae9f72571f0a9dc67406ad41f2edab0.jpg    7    7    7    7    7
#
# [12600 rows x 5 columns]

# %%
df_count = df.apply(lambda x: x.value_counts(), axis=1).fillna(0).astype(int)

# %%
df_voted = ranked[17].reset_index()
# Out:
#                                             ImageID  17
# 0      cbc5c6e168e63498590db46022617123f1fe1268.jpg  13
# 1      0e72482bf56b3581c081f7da2a6180b8792c7089.jpg   1
# 2      b549040c49190cedc41327748aeb197c1670f14d.jpg  13
# 3      4f9cb2a045c6d5b9e50ad3459ea7b791eb6e18bc.jpg  13
# 4      248428d9a4a5b6229a7081c32851b90cb8d38d0c.jpg  12
# ...                                             ...  ..
# 12595  d71d4570505d6af8f777690e63edfa8d85ea4476.jpg   1
# 12596  6cf1300e8e218716728d5820c0bab553306c2cfd.jpg   4
# 12597  8140edbba31c3a824e817e6d5fb95343199e2387.jpg   9
# 12598  030d439efe6fb5a7bafda45a393fc19f2bf57f54.jpg   1
# 12599  f1e0b9594ae9f72571f0a9dc67406ad41f2edab0.jpg   7
#
# [12600 rows x 2 columns]

# %%
df_voted.rename(columns = {17 : 'ans'}, inplace = True)

# %%
df_voted.to_csv('output22.csv', index=False)

# %%
# 이미지 확인
import matplotlib.image as img
import random
submission = pd.read_csv('/opt/ml/SpecialMission/exploration/output22.csv') # 여기에 csv파일 링크 입력
image_dir = os.path.join(test_dir, 'images')
samples = random.sample(range(0, 12600), 25)
fig, axes = plt.subplots(5, 5, figsize=(16, 16))
mask = ["Wear", "Incorrect", "Not wear"]
Gender = ["Male", "Female"]
Age = ["<30", "30<= <60", "60<="]
for i, ax in enumerate(axes.flatten()):
    c = submission.iloc[samples[i]].ans
    title = mask[int(c/6)] + " " + Gender[int((c%6)/3)] + " " +Age[(c%6)%3]
    ax.set_title(title)
    ax.axis('off')
    im = img.imread(image_dir + "/" +submission.iloc[samples[i]].ImageID)
    ax.imshow(im)
